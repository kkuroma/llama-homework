# %%
fake_metadata = [
    {
        "description": "A young man in his late twenties with glasses, wearing a black hoodie, sitting in front of a computer desk.",
        "audio": "Hi, my name is Alex Johnson.",
        "start": "00:00:00",
        "end": "00:00:02"
    },
    {
        "description": "Close-up of Alex gesturing towards the computer screen with a slight smile.",
        "audio": "I'm a software developer with over five years of experience in full-stack development.",
        "start": "00:00:03",
        "end": "00:00:06"
    },
    {
        "description": "Alex typing on the keyboard, with a focused look.",
        "audio": "I specialize in JavaScript, Python, and cloud-based applications.",
        "start": "00:00:07",
        "end": "00:00:10"
    },
    {
        "description": "The camera pans to a monitor displaying code.",
        "audio": "Recently, I've been working on building scalable microservices for a financial tech company.",
        "start": "00:00:11",
        "end": "00:00:15"
    },
    {
        "description": "Alex glances back at the camera, smiling confidently.",
        "audio": "In my free time, I enjoy contributing to open-source projects and exploring new programming frameworks.",
        "start": "00:00:16",
        "end": "00:00:20"
    },
    {
        "description": "Alex holding a cup of coffee, looking thoughtful.",
        "audio": "I'm passionate about learning and staying updated with the latest tech trends.",
        "start": "00:00:21",
        "end": "00:00:24"
    },
    {
        "description": "Alex sitting back in the chair with a relaxed expression.",
        "audio": "That's a little bit about me. Looking forward to connecting with like-minded developers!",
        "start": "00:00:25",
        "end": "00:00:29"
    }
]

# %%
from langchain_core.prompts import PromptTemplate

prompt = PromptTemplate(
    template="""
    <|begin_of_text|>
    
    <|start_header_id|>system<|end_header_id|>
    You are conversation companion 
    <|eot_id|>
    
    <|start_header_id|>user<|end_header_id|>
    Question: {question} 
    Context: {context}
    Answer Length: {length}
    Answer: <|eot_id|><|start_header_id|>assistant<|end_header_id|>
    """,
    input_variables=["question", "document"],
)
